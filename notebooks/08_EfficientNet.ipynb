# %% [markdown]
# # 🧬 EfficientNet
# This notebook explores **EfficientNet**, trains it on the EuroSAT dataset, and evaluates its performance. It is part of our study on the evolution of Convolutional Neural Networks (CNNs).
#
# As part of our architectural integrity, this notebook imports the production model directly from `src/models/` without duplicating code.

# %% [markdown]
# ## 1. Historical Background
# EfficientNet was proposed by Mingxing Tan and Quoc V. Le in 2019. It solved the scale problem in deep learning. Traditional scaling arbitrarily scales depth, width, or input resolution. EfficientNet introduced 'Compound Scaling', which uses a fixed compound coefficient to scale all three dimensions uniformly, maximizing parameter efficiency.

# %% [markdown]
# ## 2. Original Research Paper
# M. Tan and Q. V. Le. 'EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks.' ICML, 2019.

# %% [markdown]
# ## 3. Architecture Overview & Complexity
# The baseline EfficientNet-B0 uses mobile inverted bottleneck convolutions (MBConv) with squeeze-and-excitation optimization blocks.
#
# ### Parameter Count and Complexity
# EfficientNet-B0 contains only 4 million parameters but achieves state-of-the-art accuracy, utilizing ~390 million FLOPS.

# %% [markdown]
# ## 4. Import Production Model
# We import the model from `src/models/` to ensure a single source of truth.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import json

from src.models import create_model
from src.dataset import create_dataloaders
from src.training import Trainer
from src.evaluation import evaluate_model

# Instantiate EfficientNet
model = create_model("efficientnetb0", num_classes=10)
print(model)
model.summary()
# Out:
# EfficientNetB0(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (4): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (4): MBConv(
#       (block): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (5): MBConv(
#       (block): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (6): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (7): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (8): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (9): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (10): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (11): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (12): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (13): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (14): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (15): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=10, bias=True)
#   )
# )
# ============================================================
# Model Summary: EfficientNetB0
# ------------------------------------------------------------
# EfficientNetB0(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): Swish()
#   )
#   (blocks): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (4): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (4): MBConv(
#       (block): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (5): MBConv(
#       (block): Sequential(
#         (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (4): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (6): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (7): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (8): MBConv(
#       (block): Sequential(
#         (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#         (4): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (9): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (10): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (11): MBConv(
#       (block): Sequential(
#         (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (4): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (12): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (13): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (14): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#     (15): MBConv(
#       (block): Sequential(
#         (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (2): Swish()
#         (3): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (4): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#         (5): Swish()
#         (6): SqueezeExcitation(
#           (se): Sequential(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (2): Swish()
#             (3): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (4): Sigmoid()
#           )
#         )
#         (7): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (8): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       )
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): Swish()
#     (3): AdaptiveAvgPool2d(output_size=1)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=10, bias=True)
#   )
# )
# ------------------------------------------------------------
# Total Parameters: 4,020,358
# Trainable Parameters: 4,020,358
# ============================================================

# %% [markdown]
# ## 5. Dataset & DataLoaders
# We load the EuroSAT dataset (RGB) using our modular dataloader.

# %%
train_loader, val_loader, test_loader = create_dataloaders(batch_size=16)
print(f"Train batches: {len(train_loader)}")
print(f"Val batches: {len(val_loader)}")
print(f"Test batches: {len(test_loader)}")
# Out:
# Train batches: 1350
# Val batches: 169
# Test batches: 169

# %% [markdown]
# ## 6. Model Training
# We train the model using our enhanced `Trainer` framework, featuring:
# - **Early Stopping**: Validation loss monitoring with configurable patience.
# - **Learning Rate Scheduler**: Reduce learning rate when validation loss plateaus.
# - **TensorBoard Integration**: Weight, gradient, and metric tracking.
# - **Checkpointing**: Automatic saving of `best_model.pth` and `last_model.pth`.
#
# ### TensorBoard Logging
# To launch TensorBoard and visualize metrics, run in your terminal:
# ```bash
# tensorboard --logdir outputs/logs
# ```

# %%
# Set to True to run actual training.
# Set to False to skip training and load mock history.
run_training = True

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# Initialize our enhanced Trainer
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    criterion=criterion,
    scheduler_type="plateau",
    epochs=50,
    early_stopping_patience=3,
    early_stopping_min_delta=0.0,
    model_name="efficientnetb0",
    training_arguments={
        "model": "efficientnetb0",
        "epochs": 50,
        "lr": 1e-3,
        "batch_size": 32,
        "scheduler": "plateau",
        "patience": 3
    }
)

if run_training:
    # Set LIMIT_BATCHES env var to run a quick test if desired
    # os.environ["LIMIT_BATCHES"] = "5" 
    history = trainer.fit()
else:
    print("Skipping training. Loading pre-defined training history...")
    # Load history from the pre-populated path
    with open("outputs/checkpoints/efficientnetb0/history.json", "r") as f:
        history = json.load(f)
# Out:
# Training started on device: cuda
# Epoch 1/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 1
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 2/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 2
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 3/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 3
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 4/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 4
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 5/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 5
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 6/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 6
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 7/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 7
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 8/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 8
# No Improvement (1 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 9/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 9
# No Improvement (2 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 10/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 10
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 11/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 11
# No Improvement (1 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 12/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 12
# No Improvement (2 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 13/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 13
# Validation Loss Improved
# Current Learning Rate: 1.00e-03
# Epoch 14/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 14
# No Improvement (1 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 15/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 15
# No Improvement (2 / 3)
# Current Learning Rate: 1.00e-03
# Epoch 16/50 [Train]:   0%|          | 0/1350 [00:00<?, ?it/s]
# [Validation]:   0%|          | 0/169 [00:00<?, ?it/s]
# Epoch 16
# No Improvement (3 / 3)
# Current Learning Rate: 1.00e-04
# Early stopping triggered.
# Training completed in 117.94 minutes. Best Val Loss: 0.1213
# Generated training summary at /home/nishchala/Codes/Deforestation-detection/outputs/checkpoints/efficientnetb0/training_summary.md

# %% [markdown]
# ### 6.1 Resume Training (Optional)
# The Trainer saves state checkpoints (`last_model.pth` and `best_model.pth`) at the end of every epoch.
# To demonstrate resuming training from a saved checkpoint, we load the checkpoint file and continue training for further epochs.

# %%
# Set run_resume to True to load checkpoint and continue training
run_resume = False

if run_resume:
    checkpoint_path = "outputs/checkpoints/efficientnetb0/last_model.pth"
    if os.path.exists(checkpoint_path):
        # We increase the target epoch count to continue training
        trainer.epochs = 7
        trainer.load_checkpoint(checkpoint_path)
        history = trainer.fit()
    else:
        print(f"Checkpoint not found at {checkpoint_path}. Please run training first.")
else:
    print("Skipping checkpoint resume demo.")
# Out:
# Skipping checkpoint resume demo.

# %%
# Plot training curves
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history['train_acc'], label='Train Acc')
plt.plot(history['val_acc'], label='Val Acc')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history['learning_rate'], label='Learning Rate')
plt.title('Learning Rate Curve')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Model Evaluation
# We evaluate the model on the test set and calculate standard classification metrics: Accuracy, Precision, Recall, F1-score, and the Confusion Matrix.

# %%
if run_training:
    metrics, y_true, y_pred = evaluate_model(model, test_loader, criterion, trainer.device)
else:
    print("Loading pre-defined test set metrics...")
    with open("reports/metrics/efficientnetb0_metrics.json", "r") as f:
        metrics = json.load(f)
    # Mock labels for confusion matrix visualization
    y_true = np.array([i // 10 for i in range(100)])
    y_pred = np.array([i // 10 for i in range(100)])
    # Add minor noise to mock predictions for visualization
    for i in range(0, 100, 10):
        y_pred[i] = (y_pred[i] + 1) % 10

# Print results
print(f"Test Accuracy : {metrics['accuracy']:.4f}")
print(f"Precision     : {metrics['precision']:.4f}")
print(f"Recall        : {metrics['recall']:.4f}")
print(f"F1-Score      : {metrics['f1']:.4f}")
print(f"Throughput    : {metrics['images_per_second']:.2f} images/sec")
# Out:
# Test Accuracy : 0.8663
# Precision     : 0.8889
# Recall        : 0.8694
# F1-Score      : 0.8658
# Throughput    : 153.22 images/sec

# %%
classes = [
    "AnnualCrop", "Forest", "HerbaceousVegetation", "Highway",
    "Industrial", "Pasture", "PermanentCrop", "Residential",
    "River", "SeaLake"
]
cm_array = np.array(metrics["confusion_matrix"])

plt.figure(figsize=(10, 8))
sns.heatmap(cm_array, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.title(f"Confusion Matrix - EfficientNet")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
from pathlib import Path
import json
# ------------------------------------------------------------------
# Save evaluation results
# ------------------------------------------------------------------

report_dir = Path("reports/metrics")   # adjust path if needed
report_dir.mkdir(parents=True, exist_ok=True)

# Save metrics JSON
with open(report_dir / "efficientnetb0_metrics.json", "w") as f:
    json.dump(metrics, f, indent=4)

# Generate classification report
report = classification_report(
    y_true,
    y_pred,
    target_names=classes,
    digits=4
)

# Save classification report
with open(report_dir / "efficientnetb0_classification_report.txt", "w") as f:
    f.write(report)

print(f"Classification report saved to {report_dir/'efficientnetb0_classification_report.txt'}")
# Out:
# Classification report saved to reports/metrics/efficientnetb0_classification_report.txt

# %% [markdown]
# ### 7.1 Single-Image Inference Example
# Let's load a single sample image and display the model's prediction vs ground truth.

# %%
# Single-Image Inference Example
model.eval()
sample_batch = next(iter(val_loader))
img = sample_batch["image"][0]
lbl = sample_batch["label"][0].item()

with torch.no_grad():
    output = model(img.unsqueeze(0).to(trainer.device))
    pred = output.argmax(dim=1).item()
    
classes = [
    "AnnualCrop", "Forest", "HerbaceousVegetation", "Highway",
    "Industrial", "Pasture", "PermanentCrop", "Residential",
    "River", "SeaLake"
]
mean = torch.tensor([0.485,0.456,0.406]).view(3,1,1)
std = torch.tensor([0.229,0.224,0.225]).view(3,1,1)

img = img.cpu() * std + mean
img = img.clamp(0,1)

plt.figure(figsize=(4, 4))
plt.imshow(np.clip(img.permute(1, 2, 0).numpy(), 0, 1))
plt.title(f"Predicted: {classes[pred]}\nActual: {classes[lbl]}", color="green" if pred == lbl else "red")
plt.axis("off")
plt.show()
