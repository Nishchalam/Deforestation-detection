# %%
from src.data.dataloader import create_dataloaders

train_loader, val_loader, test_loader = create_dataloaders(
    batch_size=32
)

# %%
batch = next(iter(train_loader))

print(batch["image"].shape)
print(batch["label"].shape)
print(batch["class_name"][:5])
# Out:
# /home/speech/Desktop/Nishchala/Deforestation-detection/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1102: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# torch.Size([32, 3, 224, 224])
# torch.Size([32])
# ['Residential', 'Highway', 'Forest', 'Highway', 'River']

# %%
from src.data import create_dataloaders

train_loader, val_loader, test_loader = create_dataloaders(
    batch_size=32
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.data import create_dataloaders
#       2
#       3 train_loader, val_loader, test_loader = create_dataloaders(
#       4     batch_size=32
#
# ImportError: cannot import name 'create_dataloaders' from 'src.data' (unknown location)

# %%
import torch

from src.training.metrics import accuracy

outputs = torch.tensor([
    [0.1,0.9],
    [0.8,0.2],
    [0.3,0.7]
])

labels = torch.tensor([1,0,1])

print(accuracy(outputs,labels))
# Out:
# 1.0
